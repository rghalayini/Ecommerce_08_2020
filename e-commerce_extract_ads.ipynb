# %% [markdown]
# <h1> Ecommerce sales August 2020<h1>
#
# <h3> This notebook is to extract items sold that are identical at different merchants and that are both advertised or not, depending on the merchant.

# %%
import pandas as pd
filename= pd.read_csv("summer-products-with-rating-and-performance_2020-08.csv")

pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
filename.head()

# %%
df=filename.drop(columns=["title", "currency_buyer", "badge_fast_shipping", "tags", "product_color", "product_variation_size_id", "product_variation_inventory", "shipping_option_name", "shipping_option_price", "shipping_is_express", "countries_shipped_to", "inventory_total", "urgency_text","origin_country", "merchant_info_subtitle",  "merchant_has_profile_picture", "merchant_profile_picture", "product_url", "product_picture", "theme", "crawl_month"])

# %%
#check which entries have the same item title

df.duplicated(['title_orig'])

# %%
#we will only keep the items that are identical so that we can compare between the ones advertised and the ones which were not

duplicat_rows=df[df.duplicated(['title_orig'])]
duplicat_rows
# Out:
#                                              title_orig  price  retail_price  \
# 62    Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
# 67    New Fashion Summer Women Casual Dress Round Ne...   2.00             9
# 91    Women Summer Printed Plus Size Loose Casual Tr...  11.00            10
# 95    Women s New Fashion Solid Color Pants Loose Ca...   1.86             9
# 98    Women Fashion Sleeveless Deep Neck Cross Spagh...   5.79            42
# 122   Summer fashion female butterfly tank vest slee...   7.00            33
# 140   2018 New Fashion Women Casual Playsuit Ladies ...  11.00            10
# 153   New Fashion Summer Women Casual Dress Round Ne...   1.68             2
# 162   Summer mens cool sport suit Sports Wear Casual...  16.00            14
# 179   Fabric Waist Trainer Vest Hot Shaper Summer Sh...   8.00            26
# 192   NEW Women Casual Loose Solid Color Dress Short...   7.00            50
# ...

# %%
#We'll reset the index to make it better to manipulate data

duplicat_rows=duplicat_rows.reset_index(drop=True)

# %%
duplicat_rows[duplicat_rows['merchant_name']=="bebebebeworld"]
# Out:
# Empty DataFrame
# Columns: [title_orig, price, retail_price, units_sold, uses_ad_boosts, rating, rating_count, rating_five_count, rating_four_count, rating_three_count, rating_two_count, rating_one_count, badges_count, badge_local_product, badge_product_quality, has_urgency_banner, merchant_title, merchant_name, merchant_rating_count, merchant_rating, merchant_id, product_id]
# Index: []

# %%
#drop items that do not show both advertised or inadvertised. They are either 1 or 0 in the uses_ad_boosts column and we don't want that. We need both.

to_drop=[0,63,114,122,172,20, 55, 130, 27, 179, 266, 333, 29, 345, 84, 338, 183, 199, 157, 361, 166, 209, 305, 348, 31, 36, 344, 353, 18, 176, 108, 231, 64, 97, 259, 275, 16, 19, 188, 217, 66, 221, 106, 368, 252, 135, 128, 340, 234, 110, 116, 112, 287, 200, 311, 272, 318, 182, 357, 95, 324, 14,223, 320, 337, 362, 260, 173,332, 180, 358, 218,286,163,80,76,202,364,198,312,315,280,351,276,334,73,192,328,365,149,268,3,175,2,82,207,255,319,247,367,52,329,46,288, 51, 102, 22,277, 57, 167,124,191, 152,195,45,92,125,309,360,77,113,118,189,249,257,354,327,330,13,43,49,68,143,248,263,291,71,283,5,132,141,304,335,30,140,89,240,24,164,316,349,169,243,58,109,204,205,261,105,138,67,306,53,90,56,256,233,99,150,85,6,161,131,220,208,48,238,352,185,323,69,242,159,174,265,355,369,133,104,229,148,313,314,241,10,165,342,78,127,284,292,111,350,317,39,139,251,356,162,101,197,254,144,115,206,331,212,303,274,310,4,235,224,295,59,83,302,170,341,343,25,79,156,86,228,346,203,269,264,270,325,65,142,178,326,366,28,225,100,180,305,348,301,194,308,129,237,298,54]

# %%
duplicat_rows.drop(duplicat_rows.index[[to_drop]], axis=0, inplace=True)
# Out:
# C:\Users\remyg\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3941: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)

# %%
#export the current dataframe to an excel file to read it in QlikSense

duplicat_rows.to_excel(r'ads_duplicates.xlsx', index = False)
